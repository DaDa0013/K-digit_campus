# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
html = urlopen('http://www.pythonscraping.com/pages/warandpeace.html')
bs = BeautifulSoup(html.read(), 'html.parser')

# %%
nameList = set(bs.findAll('span', {'class': 'green'}))
for name in nameList:
    print(name.get_text())
# Out:
# Anna Pavlovna
# Empress Marya
# Fedorovna
# St. Petersburg
# Prince Vasili Kuragin
# The prince
# Anna
# Pavlovna Scherer
# Her Majesty
# the Empress
# King of Prussia
# Baron
# Funke
# Wintzingerode
# Anna Pavlovna's
# Abbe Morio
# le Vicomte de Mortemart
# the baron
# the prince
# the Emperor
# Dowager Empress Marya Fedorovna
# Montmorencys
# Prince Vasili
# Anna
# Pavlovna
# Rohans
# Anatole

# %% [markdown]
# <정규 표현식>
# ex) a: 1개 이상
#     b: 3개
#     c: 짝수개
#     d e 중에 하나
#     -> aa*bbb(cc)(d|e)
#     -> a+bbb

# %% [markdown]
# 내부 & 외부 링크

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 
import random
import re
import datetime


html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')

pages = set()

random.seed(datetime.datetime.now())

 

# 페이지에서 발견된 내부 링크를 모두 목록으로 만듭니다.

def getInternalLinks(bsObj, includeUrl):
    internalLinks = []

  # /로 시작하는 링크를 모두 찾습니다.
    for link in bsObj.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                internalLinks.append(link.attrs['href'])
    return internalLinks

 

# 페이지에서 발견된 외부 링크를 모두 목록으로 만듭니다.

def getExternalLinks(bsObj, excludeUrl):

    externalLinks = []

  # 현재 URL을 포함하지 않으면서 http나 www로 시작하는 링크를 모두 찾습니다.

    for link in bsObj.find_all("a",href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    
    return externalLinks

 

def splitAddress(address):

    addressParts = address.replace("http://", "").split("/")

    return addressParts

 

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html, "html.parser")
    externalLinks = getExternalLinks(bsObj, splitAddress(startingPage)[0])
    if len(externalLinks) == 0:
        internalLinks = getInternalLinks(bs,domain)
        return getNextExternalLink(internalLinks[random.randint(0,len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]

def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink("http://en.wikipedia.org/wiki/Kevin_Bacon")
    print("Random external link is: "+externalLink)
    followExternalOnly(externalLink)

followExternalOnly("http://en.wikipedia.org/wiki/Kevin_Bacon")
# Out:
# Random external link is: https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# Random external link is: https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# Random external link is: https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# Random external link is: https://www.imdb.com/name/nm0000102/
# Random external link is: http://www.biography.com/people/kevin-bacon-9542173
# Random external link is: http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# Random external link is: http://www.geneall.net/U/per_page.php?id=1014399
# Random external link is: http://data.rero.ch/02-A016294166
# Random external link is: http://www.foxnews.com/story/0,2933,343589,00.html
# Random external link is: https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# ...
